# %%
import numpy as np

ses12 = np.load("artifacts/vox_ses1-2.npy")
ses1 = np.load("artifacts/vox_ses1.npy")
ses2 = np.load("artifacts/vox_ses2.npy")
ses12_concat = np.load("artifacts/vox_ses1-2_concat.npy")

# %%
# ses1
np.mean(np.abs((ses12[0:693, :] - ses1) / ses1))
# Out:
# 0.93449897

# %%
ses12[693:, :]
# Out:
# array([[-2.7909625e+00, -1.8556207e+00,  4.6823248e-01, ...,
#          2.1452203e-01,  2.1137118e+00,  2.1074271e+00],
#        [ 1.7057819e+00, -2.6849465e+00, -2.2428718e-01, ...,
#          7.0083767e-01, -7.8013611e-01,  2.5580263e-01],
#        [ 3.8195610e-01, -1.4260759e+00, -6.4063716e-01, ...,
#          1.2116984e+00, -2.7600890e-01, -1.0459746e+00],
#        ...,
#        [-1.6903301e+00, -1.2299263e+00,  4.3727670e+00, ...,
#          6.1163777e-01,  3.3616819e+00,  3.8452460e-03],
#        [-3.7128112e-01, -9.9697989e-01,  8.1905737e+00, ...,
#         -6.0028124e+00,  1.9547609e+00, -4.1736913e-01],
#        [-1.8113356e+00, -1.0309247e+00,  3.9711475e+00, ...,
#         -3.5061579e+00,  2.5090192e-02, -7.1926761e-01]], dtype=float32)

# %%
ses2
# Out:
# array([[-2.8376172 , -0.94116694,  5.7070084 , ..., -4.4670725 ,
#         -0.94397247, -1.1606148 ],
#        [-2.8276045 , -0.30667487,  5.7676325 , ..., -3.4943798 ,
#          1.7061427 , -1.0405737 ],
#        [-2.6319575 , -1.2598019 ,  3.2190487 , ..., -3.9454558 ,
#          0.2575114 ,  1.762855  ],
#        ...,
#        [-1.5180628 , -1.8354343 ,  3.1539044 , ..., -1.1070373 ,
#         -2.4333441 , -2.5216992 ],
#        [-1.6912948 , -0.8246106 ,  5.717121  , ..., -0.3054812 ,
#         -0.85819894, -2.2225559 ],
#        [-2.294373  , -1.1967317 ,  0.9867292 , ..., -0.90926874,
#          1.526245  , -2.0487006 ]], dtype=float32)

# %%
np.all(ses12_concat[693:, :] == ses2), np.all(ses12_concat[:693, :] == ses1)
# Out:
# (True, True)
